# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as pt

# %%
df = pd.read_csv("diabetes[1].csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print ("Size of Data:",df.size)
print("Shape of Columns:",df.shape[1])
print("Shape of Rows:",df.shape[0])
# Out:
# Size of Data: 6912
# Shape of Columns: 9
# Shape of Rows: 768

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df["Age"].value_counts().sort_index(ascending=True)
# Out:
# 21    63
# 22    72
# 23    38
# 24    46
# 25    48
# 26    33
# 27    32
# 28    35
# 29    29
# 30    21
# 31    24
# 32    16
# 33    17
# 34    14
# 35    10
# 36    16
# 37    19
# 38    16
# 39    12
# 40    13
# 41    22
# 42    18
# 43    13
# 44     8
# 45    15
# 46    13
# 47     6
# 48     5
# 49     5
# 50     8
# 51     8
# 52     8
# 53     5
# 54     6
# 55     4
# 56     3
# 57     5
# 58     7
# 59     3
# 60     5
# 61     2
# 62     4
# 63     4
# 64     1
# 65     3
# 66     4
# 67     3
# 68     1
# 69     2
# 70     1
# 72     1
# 81     1
# Name: Age, dtype: int64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
print (df['Age'].value_counts().sort_index(ascending=True))

pt.figure(figsize=(10,5))
sns.countplot(df['Age'])
pt.xticks(rotation='vertical')
pt.title("Age Count",fontsize = 16)

pt.tight_layout(pad=0.5)
pt.show()
# Out:
# 21    63
# 22    72
# 23    38
# 24    46
# 25    48
# 26    33
# 27    32
# 28    35
# 29    29
# 30    21
# 31    24
# 32    16
# 33    17
# 34    14
# 35    10
# 36    16
# 37    19
# 38    16
# 39    12
# 40    13
# 41    22
# 42    18
# 43    13
# 44     8
# 45    15
# 46    13
# 47     6
# 48     5
# 49     5
# 50     8
# 51     8
# 52     8
# 53     5
# 54     6
# 55     4
# 56     3
# 57     5
# 58     7
# 59     3
# 60     5
# 61     2
# 62     4
# 63     4
# 64     1
# 65     3
# 66     4
# 67     3
# 68     1
# 69     2
# 70     1
# 72     1
# 81     1
# Name: Age, dtype: int64
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print (df['Pregnancies'].value_counts().sort_index(ascending=True))

pt.figure(figsize=(10,5))
sns.countplot(df['Pregnancies'])
pt.xlabel("Pregnency Times")
pt.xticks(rotation='vertical')
pt.title("Pregnency Times",fontsize = 16)

pt.tight_layout(pad=0.5)
pt.show()
# Out:
# 0     111
# 1     135
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 12      9
# 13     10
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pt.figure(figsize=(10,5))
sns.barplot(data=df,x='Pregnancies',y="Age")
pt.xlabel("Pregnency Times")
pt.xticks(rotation='vertical')
pt.title("Ralation Between Age and Pregnency Times",fontsize = 16)

pt.tight_layout(pad=0.5)
pt.show()

# %%
pt.figure(figsize=(12,8))
pt.subplot(2,2,1)
sns.scatterplot(data=df,x='BMI',y="Age",hue='Outcome')
pt.xticks(rotation='vertical')
pt.title("Ralation Between Age and BMI",fontsize = 16)

pt.subplot(2,2,2)
sns.scatterplot(data=df,x='BloodPressure',y="Age",hue='Outcome')
pt.xticks(rotation='vertical')
pt.title("Ralation Between Age and Blood Pressure",fontsize = 16)

pt.subplot(2,2,3)
sns.scatterplot(data=df,x='Glucose',y="Age",hue='Outcome')
pt.xticks(rotation='vertical')
pt.title("Ralation Between Age and Glucose Level",fontsize = 16)

pt.subplot(2,2,4)
sns.scatterplot(data=df,x='Insulin',y="Age",hue='Outcome')
pt.xticks(rotation='vertical')
pt.title("Ralation Between Age and Insulin",fontsize = 16)

pt.tight_layout(pad=0.5)
pt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_diabetic = df.copy()

# %%
df_diabetic.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_diabetic['Outcome'].replace(0,'Health',inplace=True)

# %%
df_diabetic['Outcome'].replace(1,'Diabetic',inplace=True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_diabetic.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age   Outcome
# 0                     0.627   50  Diabetic
# 1                     0.351   31    Health
# 2                     0.672   32  Diabetic
# 3                     0.167   21    Health
# 4                     2.288   33  Diabetic

# %%
print (df_diabetic['Outcome'].value_counts().sort_index(ascending=True))

pt.figure(figsize=(6,5))
sns.countplot(df_diabetic['Outcome'])
pt.xlabel("Diabetes Or Healty")
pt.title("Diabeties Count",fontsize = 16)

pt.tight_layout(pad=0.5)
pt.show()
# Out:
# Diabetic    268
# Health      500
# Name: Outcome, dtype: int64
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
out_df=pd.DataFrame(df.groupby('Outcome')['Outcome'].count())
colors = ['#F66D44','#FEAE65']
pt.pie(out_df['Outcome'],labels=['healthy','Diabetic'],autopct='%.0f%%',colors=colors,radius=2,explode = (0, 0.1),shadow=True)
pt.legend()
pt.show()

# %%
sns.pairplot(df,palette='OrRd_r',hue='Outcome',corner=True)
pt.show()

# %%
pt.figure(figsize=(10,5))
pt.suptitle("Diabetes Age And Pregenency",fontsize=15)
pt.subplot(1,2,1)
sns.violinplot(data = df,y='Age',x='Outcome')
pt.subplot(1,2,2)
sns.violinplot(data = df,y='Pregnancies',x='Outcome')

pt.tight_layout(pad=0.5)
pt.show()

# %%
pt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True)
pt.title("Correlation Heatmap",fontsize = 16)

pt.tight_layout(pad=0.5)
pt.show()

# %%
df.groupby('Outcome').agg({'Age': ['mean', 'median'],
                           'Glucose': ['mean', 'median'],
                           'BloodPressure': ['mean', 'median'],
                           'SkinThickness': ['mean', 'median'],
                           'Pregnancies': ['mean', 'median'],
                           'BMI': ['mean', 'median']})
# Out:
#                Age            Glucose        BloodPressure         \
#               mean median        mean median          mean median
# Outcome
# 0        31.190000   27.0  109.980000  107.0     68.184000   70.0
# 1        37.067164   36.0  141.257463  140.0     70.824627   74.0
#
#         SkinThickness        Pregnancies               BMI
#                  mean median        mean median       mean median
# Outcome
# 0           19.664000   21.0    3.298000    2.0  30.304200  30.05
# 1           22.164179   27.0    4.865672    4.0  35.142537  34.25

# %%
df["Age"].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
df["BMI"].values.sum()
# Out:
# 24570.3

# %%
y = df["Outcome"]

# %%
x = df.drop(["Outcome"],axis=1)

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
x.shape
# Out:
# (768, 8)

# %%
y.shape
# Out:
# (768,)

# %%
len(x)
# Out:
# 768

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25, random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_clf = LogisticRegression()

# %%
lr_clf.fit(x_train, y_train)
# Out:
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_clf.score(x_test, y_test)
# Out:
# 0.7395833333333334

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LogisticRegression(), x, y, cv=cv)
# Out:
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
le = LinearRegression()

# %%
le.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
le.score(x_test, y_test)
# Out:
# 0.23727790522734105

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), x, y, cv=cv)
# Out:
# array([0.32230203, 0.31158604, 0.28566905, 0.28881283, 0.26506338])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(x,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.294687
# 1              lasso    0.235553
# 2      decision_tree   -0.151166
#
#                                          best_params
# 0                                {'normalize': True}
# 1                {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
y_predict = lr_clf.predict(x)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_validate

# %%
cv_results = cross_validate(lr_clf
                    ,
                            x, y,
                            cv=10,
                            scoring=["accuracy", "precision", "recall", "f1", "roc_auc"])
# Out:
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\sagar saini\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
y_predict = lr_clf.predict(x)

# %%
from sklearn.metrics import accuracy_score

# %%
def plot_confusion_matrix(y, y_predict):
    acc = round(accuracy_score(y, y_predict), 2)
    cm = confusion_matrix(y, y_predict)
    sns.heatmap(cm, annot=True, fmt=".0f")
    pt.xlabel('y_predict')
    pt.ylabel('y')
    pt.title('Accuracy_score: {0}'.format(acc), size=10)
    pt.show()

plot_confusion_matrix(y, y_predict)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       500
#            1       0.73      0.56      0.63       268
#
#     accuracy                           0.77       768
#    macro avg       0.76      0.72      0.74       768
# weighted avg       0.77      0.77      0.77       768

# %%
from sklearn.metrics import roc_auc_score

# %%
y_prob = lr_clf.predict_proba(x)[:, 1]
roc_auc_score(y, y_prob)
# Out:
# 0.836082089552239

# %%
x.columns

random_user = x.sample(1, random_state=42)

lr_clf.predict(random_user)
# Out:
# array([0], dtype=int64)

# %%
feature_imp = pd.DataFrame({'Value': lr_clf.coef_[0], 'Feature': x.columns})
pt.figure(figsize=(10, 10))
sns.set(font_scale=1)
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value",
                                                                     ascending=False)[0:8])
pt.title('Features')
pt.tight_layout()
pt.show()
